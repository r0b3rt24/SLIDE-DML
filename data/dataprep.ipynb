# %%
import torch
import torchvision

# %%
train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('./data/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=1, shuffle=True)

# %%
train_loader.__len__()
# Out:
# 60000

# %%
len(next(iter(train_loader)))
# Out:
# 2

# %%
next(iter(train_loader))[0].reshape(1,-1).shape
# Out:
# torch.Size([1, 784])

# %%
next(iter(train_loader))[1]
# Out:
# tensor([0])

# %%
def list2String(s):  
    str1 = ""  
    for ele in s:  
        str1 += str(ele) + " "   
    
    return str1

# %%
f= open("train.txt", "w")
total = train_loader.__len__()
for i, (x,y) in enumerate(train_loader):
    x = x.reshape(1,-1).tolist()[0]
    y = y.tolist()[0]
    x_str = list2String(x)
    y_str = [0]*10
    y_str[y-1] = 1
    y_str = list2String(y_str)
    f.write("in: " + x_str + "\n")
    f.write("out: " + str(y_str) + "\n")
    print("{0}/{1} done!".format(i,total))
f.close()
# Out:
# 0/60000 done!
# 1/60000 done!
# 2/60000 done!
# 3/60000 done!
# 4/60000 done!
# 5/60000 done!
# 6/60000 done!
# 7/60000 done!
# 8/60000 done!
# 9/60000 done!
# 10/60000 done!
# 11/60000 done!
# 12/60000 done!
# 13/60000 done!
# 14/60000 done!
# 15/60000 done!
# 16/60000 done!
# 17/60000 done!
# 18/60000 done!
# 19/60000 done!
# 20/60000 done!
# 21/60000 done!
# 22/60000 done!
# 23/60000 done!
# 24/60000 done!
# 25/60000 done!
# 26/60000 done!
# 27/60000 done!
# 28/60000 done!
# 29/60000 done!
# 30/60000 done!
# 31/60000 done!
# 32/60000 done!
# 33/60000 done!
# 34/60000 done!
# 35/60000 done!
# 36/60000 done!
# 37/60000 done!
# 38/60000 done!
# 39/60000 done!
# 40/60000 done!
# 41/60000 done!
# 42/60000 done!
# 43/60000 done!
# 44/60000 done!
# 45/60000 done!
# 46/60000 done!
# 47/60000 done!
# 48/60000 done!
# 49/60000 done!
# 50/60000 done!
# 51/60000 done!
# 52/60000 done!
# 53/60000 done!
# 54/60000 done!
# 55/60000 done!
# 56/60000 done!
# 57/60000 done!
# 58/60000 done!
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("./e_data.csv")

# %%
df.head()
# Out:
#    is_mobile  n_products_viewed  visit_duration  is_returning_visitor  \
# 0          1                  0        0.657510                     0
# 1          1                  1        0.568571                     0
# 2          1                  0        0.042246                     1
# 3          1                  1        1.659793                     1
# 4          0                  1        2.014745                     1
#
#    time_of_day  user_action
# 0            3            0
# 1            2            1
# 2            1            0
# 3            1            2
# 4            1            2

# %%
for row in df.iterrows():
    data = row[1].tolist();
    label = data[0]
    x = data[1:5]
    print(x)
    break
# Out:
# [0.0, 0.657509946, 0.0, 3.0]

# %%
f= open("e_data.txt", "w")
total = 500
for i, row in enumerate(df.iterrows()):
    data = row[1].tolist();
    x = data[1:5]
    y = data[0]
    y_list = [0] * 2
    y_list[int(y)] = 1;
    x_str = list2String(x)
    y_str = list2String(y_list)
    f.write("in: " + x_str + "\n")
    f.write("out: " + y_str + "\n")
    print("{0}/{1} done!".format(i,total))
f.close()
# Out:
# 0/500 done!
# 1/500 done!
# 2/500 done!
# 3/500 done!
# 4/500 done!
# 5/500 done!
# 6/500 done!
# 7/500 done!
# 8/500 done!
# 9/500 done!
# 10/500 done!
# 11/500 done!
# 12/500 done!
# 13/500 done!
# 14/500 done!
# 15/500 done!
# 16/500 done!
# 17/500 done!
# 18/500 done!
# 19/500 done!
# 20/500 done!
# 21/500 done!
# 22/500 done!
# 23/500 done!
# 24/500 done!
# 25/500 done!
# 26/500 done!
# 27/500 done!
# 28/500 done!
# 29/500 done!
# 30/500 done!
# 31/500 done!
# 32/500 done!
# 33/500 done!
# 34/500 done!
# 35/500 done!
# 36/500 done!
# 37/500 done!
# 38/500 done!
# 39/500 done!
# 40/500 done!
# 41/500 done!
# 42/500 done!
# 43/500 done!
# 44/500 done!
# 45/500 done!
# 46/500 done!
# 47/500 done!
# 48/500 done!
# 49/500 done!
# 50/500 done!
# 51/500 done!
# 52/500 done!
# 53/500 done!
# 54/500 done!
# 55/500 done!
# 56/500 done!
# 57/500 done!
# 58/500 done!
# 59/500 done!
# 60/500 done!
# 61/500 done!
# 62/500 done!
# 63/500 done!
# 64/500 done!
# 65/500 done!
# 66/500 done!
# ...

# %%
import random
import math

# %%
r = 2
f= open("ball.txt", "w")
for i in range(200):
    theta = random.uniform(0, math.pi)
    phi = random.uniform(0, math.pi)
    x = str(math.cos(theta) * math.cos(phi))
    y = str(math.cos(theta) * math.sin(phi))
    z = str(r * math.sin(theta))
    f.write("in: " + x + " " + y + " " + z +"\n")
    f.write("out: " + str(1) + "\n")
f.close()
